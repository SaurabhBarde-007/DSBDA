# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_facebook_1.csv', delimiter=';')

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
df.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.tail()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df.dropna()
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 494             85093   Photo         3           1             7         10
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
#
# ...

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
data = df.dropna()

# %%
data.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
col_data1 = data[["Type","Category","Post Month","Post Weekday","Post Hour"]]

# %%
col_data1
# Out:
#        Type  Category  Post Month  Post Weekday  Post Hour
# 0     Photo         2          12             4          3
# 1    Status         2          12             3         10
# 2     Photo         3          12             3          3
# 3     Photo         2          12             2         10
# 4     Photo         2          12             2          3
# ..      ...       ...         ...           ...        ...
# 494   Photo         3           1             7         10
# 495   Photo         3           1             7          2
# 496   Photo         2           1             5          8
# 497   Photo         1           1             5          2
# 498   Photo         3           1             4         11
#
# [495 rows x 5 columns]

# %%
col_data2 = data[["Paid","Lifetime Post Total Reach","Lifetime Post Consumers"]]
col_data2
# Out:
#      Paid  Lifetime Post Total Reach  Lifetime Post Consumers
# 0     0.0                       2752                      109
# 1     0.0                      10460                     1361
# 2     0.0                       2413                      113
# 3     1.0                      50128                      790
# 4     0.0                       7244                      410
# ..    ...                        ...                      ...
# 494   0.0                       5400                      756
# 495   0.0                       4684                      708
# 496   0.0                       3480                      508
# 497   0.0                       3778                      572
# 498   0.0                       4156                      574
#
# [495 rows x 3 columns]

# %%
row_data1 = data.iloc[0:30]
row_data1
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             139441   Photo         2          12             4          3
# 1             139441  Status         2          12             3         10
# 2             139441   Photo         3          12             3          3
# 3             139441   Photo         2          12             2         10
# 4             139441   Photo         2          12             2          3
# 5             139441  Status         2          12             1          9
# 6             139441   Photo         3          12             1          3
# 7             139441   Photo         3          12             7          9
# 8             139441  Status         2          12             7          3
# 9             139441   Photo         3          12             6         10
# 10            139441  Status         2          12             5         10
# ...

# %%
row_data = data.iloc[[30]]
row_data
# Out:
#     Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 30            138895  Photo         2          12             4          2
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 30   0.0                       4940                             9390
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# 30                     385                      306
#
#     Lifetime Post Consumptions  \
# 30                         501
#
#     Lifetime Post Impressions by people who have liked your Page  \
# 30                                               5860
#
#     Lifetime Post reach by people who like your Page  \
# 30                                              2930
#
#     Lifetime People who have liked your Page and engaged with your post  \
# 30                                                273
#
#     comment   like  share  Total Interactions
# 30       33  107.0   22.0                 162

# %%
row_data2 = data.iloc[20:61]
row_data2
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 20            138414   Photo         2          12             1          3
# 21            138414   Photo         1          12             7         10
# 22            138414    Link         1          12             7         10
# 23            138414   Photo         3          12             7          3
# 24            138414  Status         2          12             6         10
# 25            138458  Status         2          12             6          3
# 26            138458  Status         2          12             5         11
# 27            138458   Photo         3          12             5          3
# 28            138895   Photo         2          12             5          3
# 29            138895   Video         1          12             4         11
# 30            138895   Photo         2          12             4          2
# ...

# %%
m1 = row_data1.merge(row_data2)

# %%
m1
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            138414   Photo         2          12             1          3
# 1            138414   Photo         1          12             7         10
# 2            138414    Link         1          12             7         10
# 3            138414   Photo         3          12             7          3
# 4            138414  Status         2          12             6         10
# 5            138458  Status         2          12             6          3
# 6            138458  Status         2          12             5         11
# 7            138458   Photo         3          12             5          3
# 8            138895   Photo         2          12             5          3
# 9            138895   Video         1          12             4         11
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2848                             5066
# ...

# %%
c1 = pd.concat([row_data1,row_data2])

# %%
c1
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             139441   Photo         2          12             4          3
# 1             139441  Status         2          12             3         10
# 2             139441   Photo         3          12             3          3
# 3             139441   Photo         2          12             2         10
# 4             139441   Photo         2          12             2          3
# ..               ...     ...       ...         ...           ...        ...
# 56            138329   Photo         1          11             5         11
# 57            138329   Photo         1          11             5          3
# 58            138329   Photo         1          11             4         10
# 59            138329   Photo         1          11             4          3
# 60            138185   Photo         1          11             3         11
#
# ...

# %%
sort1 = c1.sort_values(by="Post Weekday")

# %%
sort1
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 50            138353   Photo         2          11             1          9
# 20            138414   Photo         2          12             1          3
# 20            138414   Photo         2          12             1          3
# 36            138895   Photo         3          12             1          3
# 35            138895   Photo         2          12             1         11
# ..               ...     ...       ...         ...           ...        ...
# 37            138895   Photo         1          12             7         10
# 38            138895  Status         2          12             7          9
# 39            138895   Photo         1          12             7          3
# 22            138414    Link         1          12             7         10
# 23            138414   Photo         3          12             7          3
#
# ...

# %%
transpose = c1.transpose()

# %%
transpose
# Out:
#                                                         0       1       2   \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
sort1.shape
# Out:
# (71, 19)

# %%
transpose.shape
# Out:
# (19, 71)

# %%
reshape = df.melt(id_vars = "Type",value_vars=["Lifetime Post Total Reach","Post Weekday"],var_name='variable', value_name='value')

# %%
reshape
# Out:
#        Type                   variable  value
# 0     Photo  Lifetime Post Total Reach   2752
# 1    Status  Lifetime Post Total Reach  10460
# 2     Photo  Lifetime Post Total Reach   2413
# 3     Photo  Lifetime Post Total Reach  50128
# 4     Photo  Lifetime Post Total Reach   7244
# ..      ...                        ...    ...
# 995   Photo               Post Weekday      7
# 996   Photo               Post Weekday      5
# 997   Photo               Post Weekday      5
# 998   Photo               Post Weekday      4
# 999   Photo               Post Weekday      4
#
# [1000 rows x 3 columns]

# %%
reshape = pd.melt(df,id_vars = "Type",value_vars=["Lifetime Post Total Reach","Post Weekday"],var_name='variable', value_name='value')

# %%
reshape
# Out:
#        Type                   variable  value
# 0     Photo  Lifetime Post Total Reach   2752
# 1    Status  Lifetime Post Total Reach  10460
# 2     Photo  Lifetime Post Total Reach   2413
# 3     Photo  Lifetime Post Total Reach  50128
# 4     Photo  Lifetime Post Total Reach   7244
# ..      ...                        ...    ...
# 995   Photo               Post Weekday      7
# 996   Photo               Post Weekday      5
# 997   Photo               Post Weekday      5
# 998   Photo               Post Weekday      4
# 999   Photo               Post Weekday      4
#
# [1000 rows x 3 columns]
